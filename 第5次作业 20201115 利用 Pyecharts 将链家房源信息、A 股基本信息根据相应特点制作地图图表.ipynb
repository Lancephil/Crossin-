# %% [markdown]
# ## 学习前准备
# 安装 tushare 包(阅读参考文章 1)
# 在 waditu.com 上注册账号并填写个人资料，可获取 tushare pro 的 token（基础权限）
# 安装完成后，提取 A 股股票基本信息(提示:df = ts.pro_api().stock_basic())(阅读参考文章 1)

# %% [markdown]
# #### TODO1:
# 根据任务 4 所统计的上海各个区的房均价数据，利用 Pyecharts 中的 Map，以上海地图为背景作可视化展示图 (提示:可以直接定义 districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区 ', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区'])(阅读参考文章 2);

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pyecharts.charts import Bar, Pie, Page, Grid, Map, Geo
from pyecharts import options as opts
import tushare as ts

# %%
f = open('Task_4_lianjia_sale.csv',encoding = 'utf-8')
df = pd.read_csv(f)
f.close()
df_avg = df.groupby('区域')['价格'].agg(区域平均价格='mean')
df_avg = df_avg.sort_values(by = '区域平均价格')
districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
avg_price = np.round(df_avg["区域平均价格"].values).tolist()
list1 = [list(z) for z in zip(districts, avg_price)]
map1 = Map()
map1.add("上海各区房均价", list1, maptype="上海")
map1.set_global_opts(
    title_opts=opts.TitleOpts(title="上海各区房均价"),
    visualmap_opts=opts.VisualMapOpts(max_=100000, is_piecewise=False)  #最大数据范围
    )
map1.render('map1.html')
map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="29dcd12cca554353b7d4637eb90c3576" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_29dcd12cca554353b7d4637eb90c3576 = echarts.init(
#                     document.getElementById('29dcd12cca554353b7d4637eb90c3576'), 'white', {renderer: 'canvas'});
#                 var option_29dcd12cca554353b7d4637eb90c3576 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# #### TODO2:
# 导入 tushare 数据包，提取 A 股基本数据信息，利用 groupby 函数统计每个省份的公司数量，并以中国地图 为背景作相应图表(阅读参考文章 2、3、4、5)

# %%
import tushare as ts
ts.set_token('3d0f7bd25945c62fa9d359b37a4de35ad40e4e9ee9b1037dc722603e')
df1 = ts.pro_api().stock_basic()
df_num = df1.groupby('area')['name'].agg(公司数量='count')
df_area = df_num.index.values.tolist()
area_num = df_num['公司数量'].values.tolist()
list2 = [list(z) for z in zip(df_area,area_num)]
map2 = Map()
map2.add('A股上市公司数',
         list2,
         maptype = 'china')
map2.set_global_opts(
    title_opts=opts.TitleOpts(title="公司地区分布图"), # 设置标题
    visualmap_opts=opts.VisualMapOpts(max_=550, # 设置数值范围0-550
                                      is_piecewise=False # 设置标签值连续或者分段
                                     ),
                    )
map2.render('map2.html')
map2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="261e2ddadf35410db11468466d417214" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_261e2ddadf35410db11468466d417214 = echarts.init(
#                     document.getElementById('261e2ddadf35410db11468466d417214'), 'white', {renderer: 'canvas'});
#                 var option_261e2ddadf35410db11468466d417214 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...
